# %%
import numpy
import matplotlib.pyplot as plt
from numpy import diff
# %matplotlib inline

# %%
a = numpy.loadtxt('samples/0.raw', skiprows=1, delimiter=',')

# %%
plt.plot(a[:, 0], a[:, 1])

# %%
#Step1: determine youngs modulus of one file of data
#Step2: create a loop that cyles
